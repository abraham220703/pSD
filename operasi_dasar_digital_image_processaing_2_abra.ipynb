# %% [markdown]
# <a href="https://colab.research.google.com/github/abraham220703/pSD/blob/main/operasi_dasar_digital_image_processaing_2_abra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# library
import urllib.request
import cv2 # https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html
import matplotlib.pyplot as plt
import numpy as np

# %%
# get image from link google image

# first Image
urllib.request.urlretrieve (
'https://tse2.mm.bing.net/th?id=OIP.cvUQG_sKpRTiSXudOssHdwHaEo&pid=Api&P=0&h=180',
"gambar_1.png")

# Second Image
urllib.request.urlretrieve(
'https://tse1.mm.bing.net/th?id=OIP.X7QB0vE5WPmqLAZEBZ571AHaEo&pid=Api&P=0&h=180', # link from google image
"gambar_2.png")
# Out:
# ('gambar_2.png', <http.client.HTTPMessage at 0x7bf05e3ef100>)

# %%
# load image
image_1 = cv2.imread('gambar_1.png',cv2.COLOR_BGR2GRAY) # cv2.IMREAD_GRAYSCALE
image_2 = cv2.imread('gambar_2.png',cv2.COLOR_BGR2GRAY)

# Dapatkan resolusi gambar dalam piksel
width, height,channel = image_1.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")

# Dapatkan resolusi gambar dalam piksel
width_2, height_2,channel_2 = image_2.shape
print(f"Resolusi gambar 2: {width_2}x{height_2}x{channel_2} piksel")
# Out:
# Resolusi gambar 1: 180x288x3 piksel
# Resolusi gambar 2: 180x288x3 piksel

# %%
# plot figure
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.imshow(image_1)
plt.title("Gambar satu")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_2)
plt.title("Gambar dua")
plt.axis('off')

plt.show()

# %%
# hasil gambar Addition
result_add = cv2.add(image_1, image_2)
plt.imshow(result_add)
plt.show()

# Dapatkan resolusi gambar dalam piksel
width, height,channel = result_add.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")
# Out:
# Resolusi gambar 1: 180x288x3 piksel

# %%
# Membandingkan data piksel
print("Image 1 Shape: ", image_1.shape)
print("Image 2 Shape: ", image_2.shape)
print("Result Image Shape: ", result_add.shape)

# Jika ingin melihat beberapa piksel untuk perbandingan, ambil subset data
image1_pixels = image_1[:5,:5,0]  # Ambil 5x5 bagian atas dari gambar 1 #channel blue
image2_pixels = image_2[:5,:5,0]  # Ambil 5x5 bagian atas dari gambar 2 #channel blue
image3_pixels = result_add[:5, :5, 0]  # Ambil 5x5 bagian atas dari gambar 2 #channel blue

print("\nData Piksel Gambar satu \n", image1_pixels)
print("\nData Piksel Gambar dua \n", image2_pixels)
print("\nData Piksel Gambar tiga \n", image3_pixels)
# Out:
# Image 1 Shape:  (180, 288, 3)
# Image 2 Shape:  (180, 288, 3)
# Result Image Shape:  (180, 288, 3)
#
# Data Piksel Gambar satu
#  [[207 209 213 217 221]
#  [199 202 207 213 217]
#  [190 194 201 208 214]
#  [185 190 197 206 213]
#  [186 190 197 205 211]]
#
# Data Piksel Gambar dua
#  [[17 17 18 19 20]
#  [17 17 18 19 20]
#  [17 17 18 19 20]
#  [17 17 18 19 20]
#  [17 17 18 19 20]]
#
# Data Piksel Gambar tiga
#  [[224 226 231 236 241]
#  [216 219 225 232 237]
#  [207 211 219 227 234]
#  [202 207 215 225 233]
#  [203 207 215 224 231]]

# %% [markdown]
# # Logical Operations in Digital Image Processing

# %%
# get image from link google image

# first Image
urllib.request.urlretrieve(
'https://tse3.mm.bing.net/th?id=OIP.hZ3p_3qgJlqn7gospPc9TQHaEo&pid=Api&P=0&h=180', # link from google image
"gambar_1_logical.png")

# Second Image
urllib.request.urlretrieve(
'https://tse4.mm.bing.net/th?id=OIP.joXJG6DhYQlb3CEPYgSR5gHaE7&pid=Api&P=0&h=180', # link from google image
"gambar_2_logical.png")
# Out:
# ('gambar_2_logical.png', <http.client.HTTPMessage at 0x7bf05e315300>)

# %%
# load image
image1_logical = cv2.imread('gambar_1_logical.png')
image2_logical = cv2.imread('gambar_2_logical.png')

# Dapatkan resolusi gambar dalam piksel
width, height,channel = image1_logical.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")

# Dapatkan resolusi gambar dalam piksel
width_2, height_2,channel_2 = image2_logical.shape
print(f"Resolusi gambar 2: {width_2}x{height_2}x{channel_2} piksel")
# Out:
# Resolusi gambar 1: 180x288x3 piksel
# Resolusi gambar 2: 180x270x3 piksel

# %%
# plot figure
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.imshow(image1_logical, cmap='gray')
plt.title("Gambar satu")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image2_logical, cmap='gray')
plt.title("Gambar dua")
plt.axis('off')

plt.show()

# %%
# hasil gambar Addition

# Check if the images have the same dimensions
if image1_logical.shape != image2_logical.shape:
    # Resize the second image to match the dimensions of the first image
    image2_logical = cv2.resize(image2_logical, (image1_logical.shape[1], image1_logical.shape[0]))

result_logical = cv2.bitwise_not(image1_logical, image2_logical, mask=None)
plt.imshow(result_logical)
plt.show()


# Dapatkan resolusi gambar dalam piksel
width, height, channel = result_logical.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")
print(f"Resolusi gambar 2: {width}x{height}x{channel} piksel")
# Out:
# Resolusi gambar 1: 180x288x3 piksel
# Resolusi gambar 2: 180x288x3 piksel

# %%
# Membandingkan data piksel
print("Image 1 Shape: ", image1_logical.shape)
print("Image 2 Shape: ", image2_logical.shape)
print("Result Image Shape: ", result_logical.shape)

# Jika ingin melihat beberapa piksel untuk perbandingan, ambil subset data
image1_pixels_logical = image1_logical[:5,:5,0]  # Ambil 5x5 bagian atas dari gambar 1 #channel blue
image2_pixels_logical = image2_logical[:5,:5,0]  # Ambil 5x5 bagian atas dari gambar 2 #channel blue
image3_pixels_logical = result_logical[:5, :5, 0]  # Ambil 5x5 bagian atas dari gambar 2 #channel blue

print("\nData Piksel Gambar satu \n", image1_pixels_logical)
print("\nData Piksel Gambar dua \n", image2_pixels_logical)
print("\nData Piksel Gambar tiga \n", image3_pixels_logical)
# Out:
# Image 1 Shape:  (180, 288, 3)
# Image 2 Shape:  (180, 288, 3)
# Result Image Shape:  (180, 288, 3)
#
# Data Piksel Gambar satu
#  [[ 0 11 57 34 35]
#  [28 22 47 16 14]
#  [41 23 32  4  0]
#  [25  8 17  6  4]
#  [ 8  0  7  8  9]]
#
# Data Piksel Gambar dua
#  [[255 244 198 221 220]
#  [227 233 208 239 241]
#  [214 232 223 251 255]
#  [230 247 238 249 251]
#  [247 255 248 247 246]]
#
# Data Piksel Gambar tiga
#  [[255 244 198 221 220]
#  [227 233 208 239 241]
#  [214 232 223 251 255]
#  [230 247 238 249 251]
#  [247 255 248 247 246]]
